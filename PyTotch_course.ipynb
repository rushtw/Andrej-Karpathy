# %% [markdown]
# ### https://www.youtube.com/watch?v=v43SlgBcZ5Y

# %%
from IPython.display import Image
import torch

# %%
Image("tensor_dimensions.PNG")

# %%
torch.manual_seed(0)
# generate a random matrix
x=torch.randint(0, 10, (3,3))
x,x.shape
# Out:
# (tensor([[4, 9, 3],
#          [0, 3, 9],
#          [7, 3, 7]]),
#  torch.Size([3, 3]))

# %%
# sum across rows
x_sum=torch.sum(x,1,keepdim=True)
x_sum,x_sum.shape
# Out:
# (tensor([[16],
#          [12],
#          [17]]),
#  torch.Size([3, 1]))

# %%
# divide each row entry element by sum of the row.
x/x_sum
# Out:
# tensor([[0.2500, 0.5625, 0.1875],
#         [0.0000, 0.2500, 0.7500],
#         [0.4118, 0.1765, 0.4118]])
